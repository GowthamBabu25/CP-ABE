# %%
import pandas as pd
import random

# %%
df = pd.read_csv("https://raw.githubusercontent.com/GowthamBabu25/dataset/main/student_data.csv")
cols = df.columns
print(cols)
# Out:
# Index(['student_id', 'school', 'sex', 'age', 'address_type', 'family_size',
#        'parent_status', 'mother_education', 'father_education', 'mother_job',
#        'father_job', 'school_choice_reason', 'stdnt_major', 'guardian',
#        'travel_time', 'study_time', 'class_failures', 'school_support',
#        'family_support', 'extra_paid_classes', 'activities', 'nursery_school',
#        'higher_ed', 'internet_access', 'romantic_relationship',
#        'family_relationship', 'free_time', 'social', 'weekday_alcohol',
#        'weekend_alcohol', 'health', 'absences', 'grade_1', 'grade_2',
#        'final_grade'],
#       dtype='object')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/GowthamBabu25/dataset/main/student_data.csv")
num_records = 100
num_columns = 15

count = 0
policy = []
for index, row in df.iterrows():
    if count >= num_records:
        break
    selected_columns = random.sample(df.columns.tolist(), num_columns)
    output_dict = {}
    for column in selected_columns:
        value = row[column]
        output_dict[column] = value
    policy.append(output_dict)
    count += 1
output_list = []

for i, policy in enumerate(policy):
    resource = f"resource{i+1}"
    output_dict = {"resource": resource, "condition": policy}
    output_list.append(output_dict)

print(output_list)
# Out:
# [{'resource': 'resource1', 'condition': {'grade_2': 11, 'internet_access': 'no', 'weekend_alcohol': 1, 'family_size': 'Greater than 3', 'family_support': 'no', 'nursery_school': 'yes', 'final_grade': 11, 'family_relationship': 4, 'stdnt_major': 'Mathematics', 'sex': 'F', 'grade_1': 0, 'travel_time': '15 to 30 min.', 'class_failures': 0, 'romantic_relationship': 'no', 'study_time': '2 to 5 hours'}}, {'resource': 'resource2', 'condition': {'stdnt_major': 'Art', 'social': 3, 'free_time': 3, 'sex': 'F', 'school': 'GP', 'address_type': 'Urban', 'nursery_school': 'no', 'travel_time': '<15 min.', 'final_grade': 11, 'grade_1': 9, 'age': 17, 'weekend_alcohol': 1, 'family_support': 'yes', 'mother_job': 'at_home', 'weekday_alcohol': 1}}, {'resource': 'resource3', 'condition': {'mother_job': 'at_home', 'weekday_alcohol': 2, 'health': 3, 'internet_access': 'yes', 'sex': 'F', 'stdnt_major': 'Political Science', 'school_choice_reason': 'other', 'address_type': 'Urban', 'romantic_relationship': 'no', 'higher_ed': 'yes', 'family_size': 'Less than or equal to 3', 'activities': 'no', 'grade_1': 12, 'travel_time': '<15 min.', 'age': 15}}, {'resource': 'resource4', 'condition': {'health': 5, 'activities': 'yes', 'father_education': '5th to 9th grade', 'weekday_alcohol': 1, 'age': 15, 'student_id': 4, 'mother_job': 'health', 'grade_1': 14, 'final_grade': 14, 'class_failures': 0, 'grade_2': 14, 'study_time': '5 to 10 hours', 'romantic_relationship': 'yes', 'social': 2, 'family_support': 'yes'}}, {'resource': 'resource5', 'condition': {'study_time': '2 to 5 hours', 'stdnt_major': 'Biology', 'family_support': 'yes', 'address_type': 'Urban', 'health': 5, 'extra_paid_classes': 'no', 'grade_1': 11, 'social': 2, 'sex': 'F', 'mother_job': 'other', 'school_choice_reason': 'home', 'family_size': 'Greater than 3', 'higher_ed': 'yes', 'romantic_relationship': 'no', 'absences': 0}}, {'resource': 'resource6', 'condition': {'health': 5, 'travel_time': '<15 min.', 'school_support': 'no', 'school': 'GP', 'romantic_relationship': 'no', 'age': 16, 'free_time': 4, 'internet_access': 'yes', 'mother_education': 'higher education', 'grade_1': 12, 'father_job': 'other', 'weekday_alcohol': 1, 'class_failures': 0, 'nursery_school': 'yes', 'student_id': 6}}, {'resource': 'resource7', 'condition': {'school': 'GP', 'guardian': 'mother', 'mother_job': 'other', 'parent_status': 'Living together', 'address_type': 'Urban', 'father_education': '5th to 9th grade', 'travel_time': '<15 min.', 'school_choice_reason': 'home', 'sex': 'M', 'weekend_alcohol': 1, 'romantic_relationship': 'no', 'grade_2': 12, 'internet_access': 'yes', 'family_support': 'no', 'mother_education': '5th to 9th grade'}}, {'resource': 'resource8', 'condition': {'sex': 'F', 'mother_job': 'other', 'weekend_alcohol': 1, 'nursery_school': 'yes', 'higher_ed': 'yes', 'family_size': 'Greater than 3', 'romantic_relationship': 'no', 'health': 1, 'weekday_alcohol': 1, 'class_failures': 0, 'father_education': 'higher education', 'stdnt_major': 'Biology', 'student_id': 8, 'school_support': 'yes', 'extra_paid_classes': 'no'}}, {'resource': 'resource9', 'condition': {'social': 2, 'extra_paid_classes': 'no', 'mother_education': 'secondary education', 'parent_status': 'Apart', 'family_support': 'yes', 'internet_access': 'yes', 'higher_ed': 'yes', 'health': 1, 'nursery_school': 'yes', 'weekday_alcohol': 1, 'address_type': 'Urban', 'student_id': 9, 'weekend_alcohol': 1, 'family_size': 'Less than or equal to 3', 'age': 15}}, {'resource': 'resource10', 'condition': {'family_support': 'yes', 'mother_education': 'secondary education', 'activities': 'yes', 'parent_status': 'Living together', 'grade_2': 12, 'nursery_school': 'yes', 'class_failures': 0, 'internet_access': 'yes', 'guardian': 'mother', 'study_time': '2 to 5 hours', 'extra_paid_classes': 'no', 'age': 15, 'sex': 'M', 'weekday_alcohol': 1, 'father_education': 'higher education'}}, {'resource': 'resource11', 'condition': {'health': 2, 'school_choice_reason': 'reputation', 'week ...

# %%
import random
import numpy as np

def fitness_function(attribute_set, access_policies):
    coverage_score = 0
    for policy in access_policies:
        if all(attr in attribute_set for attr in policy["condition"]):
            coverage_score += 1
    redundancy_score = -len(set(attribute_set))
    exclusivity_score = 0
    for policy1 in access_policies:
        for policy2 in access_policies:
            if policy1["resource"] != policy2["resource"]:
                if set(policy1["condition"]).issubset(set(policy2["condition"])):
                    exclusivity_score -= 1
    fitness_score = 0.7 * coverage_score + 0.2 * redundancy_score + 0.1 * exclusivity_score
    return fitness_score

def generate_initial_population(num_bees, num_attributes, possible_attributes):
    population = []
    for i in range(num_bees):
        solution = random.sample(possible_attributes, num_attributes)
        population.append(solution)
    return population

def modify_solution(solution, possible_attributes):
    random_index = random.randrange(len(solution))
    solution[random_index] = random.choice(possible_attributes)
    return solution

def employed_bee_phase(population, fitness_values, access_policies, possible_attributes):
    new_population = []
    for i in range(len(population)):
        current_solution = population[i]
        new_solution = modify_solution(current_solution, possible_attributes)
        new_fitness = fitness_function(new_solution, access_policies)
        if new_fitness > fitness_values[i]:
            new_population.append(new_solution)
            fitness_values[i] = new_fitness
        else:
            new_population.append(current_solution)
    return new_population, fitness_values

def onlooker_bee_phase(population, fitness_values, access_policies, possible_attributes):
    probabilities = [fitness / sum(fitness_values) for fitness in fitness_values]
    selected_solutions = random.choices(population, weights=probabilities, k=len(population))
    new_population, fitness_values = employed_bee_phase(selected_solutions, fitness_values, access_policies, possible_attributes)
    return new_population, fitness_values

def scout_bee_phase(population, fitness_values, max_trials, num_attributes, possible_attributes, access_policies):
    trials = [0]*len(population)
    for i in range(len(population)):
        if trials[i] >= max_trials:
            population[i] = random.sample(possible_attributes, num_attributes)
            fitness_values[i] = fitness_function(population[i], access_policies)
            trials[i] = 0
        else:
            trials[i] += 1
    return population, fitness_values

def abc_algorithm(num_bees, num_attributes, max_iterations, max_trials, possible_attributes, access_policies):
    population = generate_initial_population(num_bees, num_attributes, possible_attributes)
    print(population)
    fitness_values = [fitness_function(solution, access_policies) for solution in population]

    for iteration in range(max_iterations):
        population, fitness_values = employed_bee_phase(population, fitness_values, access_policies, possible_attributes)
        fitness_values = [fitness_function(solution, access_policies) for solution in population]
        population, fitness_values = onlooker_bee_phase(population, fitness_values, access_policies, possible_attributes)
        fitness_values = [fitness_function(solution, access_policies) for solution in population]
        population, fitness_values = scout_bee_phase(population, fitness_values, max_trials, num_attributes, possible_attributes, access_policies)

    best_solution = population[fitness_values.index(max(fitness_values))]
    return best_solution

possible_attributes = ["student_id", "school", "sex", "age", "address_type", "family_size", "parent_status", "mother_education", "father_education", "mother_job", "father_job", "school_choice_reason", "stdnt_major", "guardian", "travel_time", "study_time", "class_failures", "school_support", "family_support", "extra_paid_classes", "activities", "nursery_school", "higher_ed", "internet_access", "romantic_relationship", "family_relationship", "free_time", "social", "weekday_alcohol", "weekend_alcohol", "health", "absences", "grade_1", "grade_2", "final_grade"]
access_policies = output_list
best_attribute_set = abc_algorithm(num_bees=100, num_attributes=5, max_iterations=50, max_trials=10, possible_attributes=possible_attributes, access_policies=access_policies)
print("Selected attribute set:", best_attribute_set)
# Out:
# [['school', 'extra_paid_classes', 'activities', 'family_support', 'address_type'], ['activities', 'sex', 'nursery_school', 'school_choice_reason', 'mother_education'], ['parent_status', 'guardian', 'age', 'grade_2', 'free_time'], ['sex', 'health', 'stdnt_major', 'grade_1', 'family_size'], ['weekday_alcohol', 'study_time', 'school_choice_reason', 'age', 'health'], ['address_type', 'weekday_alcohol', 'family_size', 'father_job', 'extra_paid_classes'], ['family_size', 'social', 'sex', 'absences', 'age'], ['school_choice_reason', 'higher_ed', 'guardian', 'age', 'internet_access'], ['romantic_relationship', 'guardian', 'student_id', 'internet_access', 'grade_2'], ['romantic_relationship', 'guardian', 'father_job', 'extra_paid_classes', 'class_failures'], ['father_education', 'father_job', 'study_time', 'school', 'school_support'], ['guardian', 'extra_paid_classes', 'absences', 'family_support', 'student_id'], ['stdnt_major', 'student_id', 'father_education', 'absences', 'sex'], ['internet_access', 'sex', 'nursery_school', 'student_id', 'guardian'], ['mother_job', 'school_choice_reason', 'free_time', 'school_support', 'weekday_alcohol'], ['father_job', 'mother_job', 'nursery_school', 'family_size', 'address_type'], ['school', 'family_size', 'weekday_alcohol', 'school_support', 'activities'], ['address_type', 'school_choice_reason', 'weekday_alcohol', 'guardian', 'student_id'], ['health', 'higher_ed', 'age', 'study_time', 'school_support'], ['family_relationship', 'higher_ed', 'internet_access', 'family_size', 'school'], ['travel_time', 'mother_education', 'parent_status', 'stdnt_major', 'mother_job'], ['father_job', 'health', 'travel_time', 'parent_status', 'class_failures'], ['guardian', 'higher_ed', 'mother_education', 'final_grade', 'internet_access'], ['stdnt_major', 'father_education', 'grade_2', 'activities', 'mother_education'], ['school_support', 'school', 'weekday_alcohol', 'internet_access', 'school_choice_reason'], ['age', 'internet_access', 'grade_1', 'activities', 'sex'], ['guardian', 'grade_2', 'higher_ed', 'study_time', 'address_type'], ['final_grade', 'study_time', 'father_job', 'internet_access', 'extra_paid_classes'], ['school_support', 'health', 'travel_time', 'activities', 'school'], ['weekday_alcohol', 'internet_access', 'family_size', 'mother_education', 'romantic_relationship'], ['family_size', 'family_relationship', 'weekend_alcohol', 'nursery_school', 'school_choice_reason'], ['sex', 'grade_2', 'student_id', 'father_education', 'weekend_alcohol'], ['age', 'sex', 'father_education', 'study_time', 'family_relationship'], ['class_failures', 'extra_paid_classes', 'social', 'romantic_relationship', 'study_time'], ['class_failures', 'school_support', 'guardian', 'student_id', 'grade_2'], ['school_choice_reason', 'absences', 'romantic_relationship', 'social', 'age'], ['school', 'grade_2', 'health', 'family_size', 'free_time'], ['weekend_alcohol', 'family_relationship', 'final_grade', 'father_education', 'study_time'], ['nursery_school', 'weekday_alcohol', 'school', 'activities', 'parent_status'], ['health', 'school_support', 'free_time', 'activities', 'final_grade'], ['grade_1', 'health', 'absences', 'stdnt_major', 'nursery_school'], ['extra_paid_classes', 'romantic_relationship', 'school_choice_reason', 'sex', 'absences'], ['travel_time', 'mother_job', 'school_support', 'school', 'stdnt_major'], ['weekday_alcohol', 'grade_2', 'romantic_relationship', 'free_time', 'internet_access'], ['weekend_alcohol', 'health', 'school_choice_reason', 'nursery_school', 'grade_1'], ['family_relationship', 'mother_education', 'class_failures', 'grade_1', 'absences'], ['family_relationship', 'higher_ed', 'family_size', 'class_failures', 'father_education'], ['mother_job', 'nursery_school', 'student_id', 'internet_access', 'grade_2'], ['grade_2', 'school_choice_reason', 'higher_ed', 'parent_status', 'family_relationship'], ['study_time', 'family_size', 'social', 'class_failures', 'internet_access'], ['grade_1', 'stdnt_major', 'social ...
# Selected attribute set: ['higher_ed', 'stdnt_major', 'class_failures', 'extra_paid_classes', 'stdnt_major']
